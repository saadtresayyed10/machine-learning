# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
dataset = pd.read_csv("dirty_cafe_sales.csv")
dataset.head(5)
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
dataset.shape
# Out:
# (10000, 8)

# %% [markdown]
# # Total missing values

# %%
dataset.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %% [markdown]
# # Plotting graph (before)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# # Dropping columns with most missing values

# %%
dataset.drop(columns=["Location"], inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Transaction Date     159
# dtype: int64

# %% [markdown]
# # Dropping all rows with null values

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Transaction Date    0
# dtype: int64

# %% [markdown]
# # Percentage of removed null values

# %%
dataset.shape
# Out:
# (6737, 7)

# %%
print(((10000 - 6737)/10000)*100,"%")
# Out:
# 32.629999999999995 %

# %% [markdown]
# # Plotting graph (after)

# %%
sns.heatmap(dataset.isnull())
plt.show()
